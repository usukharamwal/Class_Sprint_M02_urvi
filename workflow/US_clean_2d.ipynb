# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
read_2d = pd.read_csv('../data/2d-data.csv')
read_2d
# Out:
#              x         y
# 0     2.182405  2.098743
# 1     2.068501  2.220172
# 2     2.323348  1.857437
# 3     1.897711  2.190042
# 4     1.853192  2.168086
# ...        ...       ...
# 5995  2.408327  2.866414
# 5996  2.112511  2.340011
# 5997  2.362519  2.309034
# 5998  2.393101  2.230595
# 5999  2.748144  2.455275
#
# [6000 rows x 2 columns]

# %%
read_2d.x.describe()
# Out:
# count    6000.000000
# mean        2.204573
# std         0.280911
# min         1.239564
# 25%         1.996830
# 50%         2.206386
# 75%         2.410492
# max         3.100052
# Name: x, dtype: float64

# %%
read_2d.y.describe()
# Out:
# count    6000.000000
# mean        2.200229
# std         0.285389
# min         1.359797
# 25%         1.986037
# 50%         2.195402
# 75%         2.411082
# max         3.182196
# Name: y, dtype: float64

# %%
import scipy.stats as stats

Pearson_corr_coeff, p_value1 = stats.pearsonr(read_2d["x"], read_2d["y"])
Sp_corr_coeff, p_value2 = stats.spearmanr(read_2d["x"], read_2d["y"])


print(f"Pearson r:  {Pearson_corr_coeff:.3f}")
print(f"Spearman ρ: {Sp_corr_coeff:.3f}")
# Out:
# Pearson r:  0.493
# Spearman ρ: 0.527
