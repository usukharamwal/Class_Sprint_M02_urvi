# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
read_MM = pd.read_csv('../data/1d-multi-method-data.csv')
read_MM
# Out:
#         method    AUCROC
# 0     Proposed  0.700433
# 1     Proposed  0.699677
# 2     Proposed  0.694899
# 3     Proposed  0.611460
# 4     Proposed  0.623799
# ..         ...       ...
# 95  Baseline_9  0.572251
# 96  Baseline_9  0.513158
# 97  Baseline_9  0.502816
# 98  Baseline_9  0.573068
# 99  Baseline_9  0.593619
#
# [100 rows x 2 columns]

# %%
read_MM.groupby('method').AUCROC.mean().sort_values(ascending=False)
# Out:
# method
# Baseline_2    0.916858
# Baseline_1    0.766974
# Proposed      0.661321
# Baseline_9    0.557234
# Baseline_3    0.461854
# Baseline_7    0.388454
# Baseline_6    0.320925
# Baseline_5    0.269172
# Baseline_4    0.226200
# Baseline_8    0.192495
# Name: AUCROC, dtype: float64

# %%
read_MM.groupby('method').AUCROC.median().sort_values(ascending=False)
# Out:
# method
# Baseline_2    0.907718
# Baseline_1    0.767523
# Proposed      0.669363
# Baseline_9    0.572660
# Baseline_3    0.455904
# Baseline_7    0.391778
# Baseline_6    0.323728
# Baseline_5    0.266379
# Baseline_4    0.225000
# Baseline_8    0.191516
# Name: AUCROC, dtype: float64
